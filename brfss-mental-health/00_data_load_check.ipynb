# %% [markdown]
# Behavioral Risk Factor Surveillance Systerm (BRFSS)
# 2023 data
#
# Amanda Shero
# March 9, 2026
#
# Notebook loads the 2023 data and confirms the data loaded correctly and completely.

# %%
import pyreadstat ## not needed if using pandas to export file
import pandas as pd

# %%
# Note: pd.read_sas used instead of pyreadstat due to XPT character encoding issue
df = pd.read_sas('LLCP2023.XPT', format='xport', encoding='latin-1')
print(df.shape)
print(df.columns[:10])
# Out:
# (433323, 350)
# Index(['_STATE', 'FMONTH', 'IDATE', 'IMONTH', 'IDAY', 'IYEAR', 'DISPCODE',
#        'SEQNO', '_PSU', 'CTELENM1'],
#       dtype='str')

# %%
print(df['MENTHLTH'].value_counts().head(10))
# Out:
# MENTHLTH
# 88.0    257026
# 30.0     25573
# 2.0      23878
# 5.0      19959
# 10.0     15426
# 3.0      15394
# 1.0      14173
# 15.0     14152
# 20.0      9065
# 4.0       7810
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    _STATE  FMONTH     IDATE IMONTH IDAY IYEAR  DISPCODE       SEQNO  \
# 0     1.0     1.0  03012023     03   01  2023    1100.0  2023000001
# 1     1.0     1.0  01062023     01   06  2023    1100.0  2023000002
# 2     1.0     1.0  03082023     03   08  2023    1100.0  2023000003
# 3     1.0     1.0  03062023     03   06  2023    1100.0  2023000004
# 4     1.0     1.0  01062023     01   06  2023    1100.0  2023000005
#
#            _PSU  CTELENM1  ...      DROCDY4_  _RFBING6      _DRNKWK2  \
# 0  2.023000e+09       1.0  ...  5.397605e-79       1.0  5.397605e-79
# 1  2.023000e+09       1.0  ...  5.397605e-79       1.0  5.397605e-79
# 2  2.023000e+09       1.0  ...  5.397605e-79       1.0  5.397605e-79
# 3  2.023000e+09       1.0  ...  5.397605e-79       1.0  5.397605e-79
# 4  2.023000e+09       1.0  ...  7.000000e+00       1.0  4.700000e+01
#
#    _RFDRHV8  _FLSHOT7  _PNEUMO3  _AIDTST4  _RFSEAT2  _RFSEAT3  _DRNKDRV
# ...
